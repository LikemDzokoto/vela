# %% [markdown]
# ### Get Coins with < $100 Million Markt Cap  from Binance API and save to a csv file

# %%
import os 
from binance.client import Client 
import pandas as pd 
from dotenv  import  load_dotenv 

load_dotenv()

API_KEY = os.getenv('BINANCE_API_KEY')
API_SECRET = os.getenv('BINANCE_API_SECRET')

client  = Client(API_KEY,API_SECRET)

def get_small_cap_coins(market_cap_threshold=100_000_000):
    """
    Fetch recently listed coins with market cap under the specified threshold.
    """
    #  all tickers
    tickers = client.get_all_tickers()
    
    # (market cap under $100M)
    small_cap_coins = []
    for ticker in tickers:
        symbol = ticker['symbol']
        if symbol.endswith('USDT'):  
            try:
                # 24hr ticker data for market cap calculation
                ticker_24hr = client.get_ticker(symbol=symbol)
                volume = float(ticker_24hr['quoteVolume'])
                price = float(ticker_24hr['lastPrice'])
                market_cap = volume * price
                
                if market_cap < market_cap_threshold:
                    small_cap_coins.append(symbol)
            except Exception as e:
                print(f"Error processing {symbol}: {e}")
    
    return small_cap_coins

def fetch_price_volume_data(symbol, interval='5m', limit=60):
    """
    Fetch OHLC and volume data for a given symbol.
    """
    try:
        klines = client.get_klines(symbol=symbol, interval=interval, limit=limit)
        return [{
            'timestamp': kline[0],
            'open': float(kline[1]),
            'high': float(kline[2]),
            'low': float(kline[3]),
            'close': float(kline[4]),
            'volume': float(kline[5])
        } for kline in klines]
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None


if __name__ == "__main__":
  
    small_cap_coins = get_small_cap_coins()
    print(f"Small-cap coins: {small_cap_coins}")

    small_cap_df = pd.DataFrame(small_cap_coins , columns=['Symbol'])
    small_cap_df.to_csv('small_cap_coins.csv', index = False)
    
    if small_cap_coins:
        coin_data = fetch_price_volume_data(small_cap_coins[0])
        if coin_data:
            coin_df = pd.DataFrame(coin_data)
            coin_df.to_csv(f'{small_cap_coins[0]}_price_volume_data.csv', index=False)
        print(f"Sample data for {small_cap_coins[0]}: {coin_data[:1]}")

# %% [markdown]
# ### Improved Code and added progression bar   for script

# %%
import os
from binance.client import Client
import pandas as pd
from dotenv import load_dotenv
from tqdm import tqdm

# Load environment variables
load_dotenv()

API_KEY = os.getenv('BINANCE_API_KEY')
API_SECRET = os.getenv('BINANCE_API_SECRET')

client = Client(API_KEY, API_SECRET)

def get_filtered_symbols(market_cap_threshold=100_000_000, min_volume=1_000_000, min_days_listed=90):
    """
    Fetch USDT trading pairs with specific conditions:
      - Market cap below the threshold.
      - Minimum 24-hour trading volume.
      - Listed for at least the specified number of days.

    Args:
        market_cap_threshold (float): Maximum market cap.
        min_volume (float): Minimum 24-hour trading volume.
        min_days_listed (int): Minimum number of days listed.

    Returns:
        list: Filtered symbols meeting the criteria.
    """
    print("Fetching exchange info...")
    exchange_info = client.get_exchange_info()
    symbols = [
        symbol_info['symbol'] for symbol_info in exchange_info['symbols']
        if symbol_info['symbol'].endswith('USDT') and symbol_info['status'] == 'TRADING'
    ]

    filtered_symbols = []
    print("Processing symbols...")
    for symbol in tqdm(symbols):
        try:
            ticker_24hr = client.get_ticker(symbol=symbol)
            volume = float(ticker_24hr['quoteVolume'])
            price = float(ticker_24hr['lastPrice'])
            market_cap = volume * price

            # Fetch listing age (minimum 90 daily klines required)
            klines = client.get_klines(symbol=symbol, interval='1d', limit=min_days_listed)

            if (
                market_cap < market_cap_threshold
                and volume >= min_volume
                and len(klines) >= min_days_listed
            ):
                filtered_symbols.append({
                    'symbol': symbol,
                    'market_cap': market_cap,
                    'volume': volume,
                    'days_listed': len(klines)
                })
        except Exception as e:
            print(f"Error processing {symbol}: {e}")

    return sorted(filtered_symbols, key=lambda x: x['market_cap'])

def fetch_historical_data(symbol, interval='15m', days=14):
    """
    Fetch historical OHLC and volume data for a given symbol.

    Args:
        symbol (str): The cryptocurrency trading pair symbol (e.g., BTCUSDT).
        interval (str): The time interval for the kline data (e.g., '15m').
        days (int): Number of days to fetch data for.

    Returns:
        pd.DataFrame: DataFrame containing OHLC and volume data.
    """
    try:
        total_bars = days * 96  # 96 bars per day for 15m intervals
        print(f"Fetching historical data for {symbol} ({interval}, {days} days)...")
        klines = client.get_klines(symbol=symbol, interval=interval, limit=total_bars)

        data = [{
            'timestamp': pd.to_datetime(kline[0], unit='ms'),
            'open': float(kline[1]),
            'high': float(kline[2]),
            'low': float(kline[3]),
            'close': float(kline[4]),
            'volume': float(kline[5])
        } for kline in klines]

        return pd.DataFrame(data)

    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return pd.DataFrame()

def save_to_csv(data, filename):
    """
    Save a list of dictionaries or DataFrame to a CSV file.

    Args:
        data (list or pd.DataFrame): Data to save.
        filename (str): File name for the CSV.
    """
    if isinstance(data, list):
        df = pd.DataFrame(data)
    else:
        df = data

    df.to_csv(filename, index=False)
    print(f"Saved data to {filename}.")

if __name__ == "__main__":
    # Step 1: Filter symbols
    filtered_symbols = get_filtered_symbols()

    if not filtered_symbols:
        print("No symbols met the criteria.")
    else:
        print(f"Filtered symbols found: {len(filtered_symbols)}")
        save_to_csv(filtered_symbols, "filtered_symbols.csv")

        # Step 2: Fetch historical data for each filtered symbol
        for symbol_info in filtered_symbols:
            symbol_name = symbol_info['symbol']
            historical_data = fetch_historical_data(symbol_name, interval='15m', days=14)

            if not historical_data.empty:
                filename = f"{symbol_name}_15m_data.csv"
                save_to_csv(historical_data, filename)
            else:
                print(f"No historical data found for {symbol_name}.")

# %% [markdown]
# ### get the circulating supply for every symbol you fetch from the Binance API and then use the CoinGecko API  total ciruclating supply to get market cap

# %%
import requests

import concurrent.futures




def get_binance_symbols():
    """Fetch all trading pairs from Binance."""
    exchange_info = binance_client.get_exchange_info()
    symbols = [symbol_info['symbol'] for symbol_info in exchange_info['symbols'] if symbol_info['status'] == 'TRADING']
    return symbols

def get_price(symbol):
    """Get current price for a given symbol from Binance."""
    try:
        ticker = binance_client.get_ticker(symbol=symbol)
        return float(ticker['lastPrice'])
    except Exception as e:
        print(f"Error fetching price for {symbol}: {e}")
        return None

def get_circulating_supply(symbol):
    """Fetch circulating supply from CoinGecko."""
    coingecko_url = f"https://api.coingecko.com/api/v3/simple/price?ids={symbol}&vs_currencies=usd&include_market_cap=true"
    try:
        response = requests.get(coingecko_url)
        data = response.json()
        return data[symbol]['market_cap']
    except Exception as e:
        print(f"Error fetching circulating supply for {symbol}: {e}")
        return None

def calculate_market_cap(symbol):
    """Calculate market cap using price and circulating supply."""
    # Remove USDT from the symbol
    base_symbol = symbol.replace('USDT', '')
    
    price = get_price(symbol)
    circulating_supply = get_circulating_supply(base_symbol)
    
    if price is not None and circulating_supply is not None:
        market_cap = circulating_supply * price
        return symbol, market_cap
    return symbol, None

def main():
    symbols = get_binance_symbols()
    
    # Filter USDT pairs
    usdt_symbols = [symbol for symbol in symbols if symbol.endswith('USDT')]
    
    # Use ThreadPoolExecutor to fetch data in parallel
    with concurrent.futures.ThreadPoolExecutor() as executor:
        market_caps = list(executor.map(calculate_market_cap, usdt_symbols))
    
    # Filter out None values and create DataFrame
    valid_market_caps = [(symbol, cap) for symbol, cap in market_caps if cap is not None]
    
    # Create a DataFrame and save to CSV
    # df = pd.DataFrame(valid_market_caps, columns=['Symbol', 'Market Cap'])
    # df.to_csv('market_caps.csv', index=False)
    
    # print("Market caps calculated and saved to market_caps.csv")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Binance API doesnt support giving market Cap info directly so i am using  2 weeks trading volume to approximate market cap  and it seems binance does not provide the date a coin was  listed so i would be fetching  historical 90 days of trading .

# %%
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from binance.client import Client
from dotenv import load_dotenv
import os 
from tqdm import tqdm


load_dotenv()

API_KEY = os.getenv('BINANCE_API_KEY')
API_SECRET = os.getenv('BINANCE_API_SECRET')

client = Client(API_KEY, API_SECRET)



def get_filtered_symbols_parallel(market_cap_threshold=100_000_000, min_volume=1_000_000, min_days_listed=90):
    """
    Fetch USDT trading pairs with specific conditions using parallel processing:
      - Market cap below the threshold.
      - Minimum 24-hour trading volume.
      - Listed for at least the specified number of days.

    Args:
        market_cap_threshold (float): Maximum market cap.
        min_volume (float): Minimum 24-hour trading volume.
        min_days_listed (int): Minimum number of days listed.

    Returns:
        list: Filtered symbols meeting the criteria.
    """
    print("Fetching exchange info...")
    exchange_info = client.get_exchange_info()
    symbols = [
        symbol_info['symbol'] for symbol_info in exchange_info['symbols']
        if symbol_info['symbol'].endswith('USDT') and symbol_info['status'] == 'TRADING'
    ]

    def process_symbol(symbol):
        try:
            ticker_24hr = client.get_ticker(symbol=symbol)
            volume = float(ticker_24hr['quoteVolume'])
            price = float(ticker_24hr['lastPrice'])
            market_cap = volume * price

            # Fetch listing age (minimum 90 daily klines required)
            klines = client.get_klines(symbol=symbol, interval='1d', limit=min_days_listed)

            if (
                market_cap < market_cap_threshold
                and volume >= min_volume
                and len(klines) >= min_days_listed
            ):
                return {
                    'symbol': symbol,
                    'market_cap': market_cap,
                    'volume': volume,
                    'days_listed': len(klines)
                }
        except Exception as e:
            print(f"Error processing {symbol}: {e}")
        return None

    print("Processing symbols in parallel...")
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(process_symbol, symbols), total=len(symbols), desc="Processing symbols"))

    filtered_symbols = [result for result in results if result is not None]
    return sorted(filtered_symbols, key=lambda x: x['market_cap'])



def main():
    
    filtered_symbols = get_filtered_symbols_parallel()

    if not filtered_symbols:
        print("No symbols met the criteria.")
    else:
        print(f"Filtered symbols found: {len(filtered_symbols)}")
        
        # Print out the processed symbols
        for symbol_data in filtered_symbols:
            print(symbol_data)
    
    
    
    # df = pd.DataFrame(valid_market_caps, columns=['Symbol', 'Market Cap'])
    # df.to_csv('market_caps.csv', index=False)
    
    # print("Market caps calculated and saved to market_caps.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching exchange info...
# Processing symbols in parallel...
# Processing symbols: 100%|██████████| 388/388 [00:43<00:00,  8.84it/s]
# Filtered symbols found: 271
# {'symbol': 'BTTCUSDT', 'market_cap': 3.431525483660725, 'volume': 3036748.21562896, 'days_listed': 90}
# {'symbol': 'XECUSDT', 'market_cap': 124.0905513619951, 'volume': 3351081.5922764, 'days_listed': 90}
# {'symbol': 'WINUSDT', 'market_cap': 260.7597851457095, 'volume': 2501292.90307635, 'days_listed': 90}
# {'symbol': 'LUNCUSDT', 'market_cap': 902.8821380995248, 'volume': 7712985.9738555, 'days_listed': 90}
# {'symbol': 'SPELLUSDT', 'market_cap': 1616.107384083942, 'volume': 1995194.3013382, 'days_listed': 90}
# {'symbol': 'SHIBUSDT', 'market_cap': 1731.5824583994297, 'volume': 71701136.9937652, 'days_listed': 90}
# {'symbol': 'BONKUSDT', 'market_cap': 2368.479958411594, 'volume': 68255906.58246668, 'days_listed': 90}
# {'symbol': 'VTHOUSDT', 'market_cap': 3622.840636113856, 'volume': 1250980.882636, 'days_listed': 90}
# {'symbol': '1000SATSUSDT', 'market_cap': 4383.214340042455, 'volume': 23045290.9571107, 'days_listed': 90}
# {'symbol': 'LEVERUSDT', 'market_cap': 4431.338460196178, 'volume': 2306787.329618, 'days_listed': 90}
# {'symbol': 'DENTUSDT', 'market_cap': 4468.847834880089, 'volume': 2920815.578353, 'days_listed': 90}
# {'symbol': 'DOGSUSDT', 'market_cap': 4705.38814560769, 'volume': 8353254.297191, 'days_listed': 90}
# {'symbol': 'PEPEUSDT', 'market_cap': 5843.90738429528, 'volume': 280283327.78394634, 'days_listed': 90}
# {'symbol': 'SCUSDT', 'market_cap': 7241.087052575712, 'volume': 1262833.458768, 'days_listed': 90}
# {'symbol': 'LINAUSDT', 'market_cap': 8749.26867256464, 'volume': 1575025.863648, 'days_listed': 90}
# {'symbol': 'MBLUSDT', 'market_cap': 9067.924525823028, 'volume': 2708460.133161, 'days_listed': 90}
# {'symbol': 'HOTUSDT', 'market_cap': 10316.998387825528, 'volume': 3992646.434917, 'days_listed': 90}
# {'symbol': 'SLPUSDT', 'market_cap': 10530.056992292588, 'volume': 2548416.503459, 'days_listed': 90}
# {'symbol': 'FLOKIUSDT', 'market_cap': 10664.039675710088, 'volume': 54497340.94291746, 'days_listed': 90}
# {'symbol': 'IQUSDT', 'market_cap': 13525.267066512397, 'volume': 1817667.929917, 'days_listed': 90}
# {'symbol': 'AMBUSDT', 'market_cap': 13740.8703722724, 'volume': 1671638.73142, 'days_listed': 90}
# {'symbol': 'IOSTUSDT', 'market_cap': 17843.972699475147, 'volume': 2493568.012783, 'days_listed': 90}
# {'symbol': 'COSUSDT', 'market_cap': 18247.153677861843, 'volume': 2249679.9011049, 'days_listed': 90}
# {'symbol': 'STMXUSDT', 'market_cap': 20191.45220363466, 'volume': 3535537.069451, 'days_listed': 90}
# {'symbol': 'HMSTRUSDT', 'market_cap': 20913.78794329932, 'volume': 6326009.66222, 'days_listed': 90}
# {'symbol': 'GUSDT', 'market_cap': 46497.56792328449, 'volume': 1469117.46993, 'days_listed': 90}
# {'symbol': 'AMPUSDT', 'market_cap': 49800.89926984371, 'volume': 6215788.725642, 'days_listed': 90}
# {'symbol': 'NOTUSDT', 'market_cap': 54341.26579971224, 'volume': 8072083.452126, 'days_listed': 90}
# {'symbol': 'CELRUSDT', 'market_cap': 54531.11144557434, 'volume': 2643291.878118, 'days_listed': 90}
# {'symbol': 'CKBUSDT', 'market_cap': 54532.147177856554, 'volume': 4280724.325132, 'days_listed': 90}
# {'symbol': 'BETAUSDT', 'market_cap': 63281.28689364371, 'volume': 1350144.80251, 'days_listed': 90}
# {'symbol': 'USTCUSDT', 'market_cap': 64137.6238447143, 'volume': 3096939.82833, 'days_listed': 90}
# {'symbol': 'PDAUSDT', 'market_cap': 64562.85991130945, 'volume': 1358932.012446, 'days_listed': 90}
# {'symbol': 'TFUELUSDT', 'market_cap': 70874.76034442519, 'volume': 1045813.19676, 'days_listed': 90}
# {'symbol': 'TLMUSDT', 'market_cap': 71621.791775826, 'volume': 4862307.6562, 'days_listed': 90}
# {'symbol': 'DATAUSDT', 'market_cap': 71866.54378079271, 'volume': 1427339.499122, 'days_listed': 90}
# {'symbol': 'RVNUSDT', 'market_cap': 72577.24470491624, 'volume': 3154161.004125, 'days_listed': 90}
# {'symbol': 'ARPAUSDT', 'market_cap': 79865.0158116277, 'volume': 1509735.648613, 'days_listed': 90}
# {'symbol': 'FIOUSDT', 'market_cap': 80430.74098233119, 'volume': 1818465.76944, 'days_listed': 90}
# {'symbol': '1MBABYDOGEUSDT', 'market_cap': 82574.84611861597, 'volume': 24359798.8431813, 'days_listed': 90}
# {'symbol': 'FLMUSDT', 'market_cap': 84599.64476852, 'volume': 1073599.5529, 'days_listed': 90}
# {'symbol': 'WAXPUSDT', 'market_cap': 87397.3690241172, 'volume': 1967522.94066, 'days_listed': 90}
# {'symbol': 'SUNUSDT', 'market_cap': 89846.3865430701, 'volume': 3414913.96971, 'days_listed': 90}
# {'symbol': 'ZILUSDT', 'market_cap': 92222.04969762528, 'volume': 4013144.025136, 'days_listed': 90}
# {'symbol': 'VIDTUSDT', 'market_cap': 93285.857625155, 'volume': 2755859.9003, 'days_listed': 90}
# {'symbol': 'NEIROUSDT', 'market_cap': 93953.8560570794, 'volume': 87872219.7295942, 'days_listed': 90}
# {'symbol': 'REZUSDT', 'market_cap': 102676.19763449537, 'volume': 2604672.694939, 'days_listed': 90}
# {'symbol': 'JSTUSDT', 'market_cap': 107199.0804667521, 'volume': 2608250.133011, 'days_listed': 90}
# {'symbol': 'REIUSDT', 'market_cap': 111630.2490685463, 'volume': 1817194.35241, 'days_listed': 90}
# {'symbol': 'MEMEUSDT', 'market_cap': 119085.78354950759, 'volume': 10427826.93078, 'days_listed': 90}
# {'symbol': 'ANKRUSDT', 'market_cap': 120785.67316733346, 'volume': 3128352.063386, 'days_listed': 90}
# {'symbol': 'ACHUSDT', 'market_cap': 124712.3005806033, 'volume': 4573241.67879, 'days_listed': 90}
# {'symbol': 'SYSUSDT', 'market_cap': 129755.25083105, 'volume': 1050649.8043, 'days_listed': 90}
# {'symbol': 'BOMEUSDT', 'market_cap': 136802.28442565698, 'volume': 19956569.5734, 'days_listed': 90}
# {'symbol': 'TUSDT', 'market_cap': 144845.52351956177, 'volume': 4903369.110344, 'days_listed': 90}
# {'symbol': 'REQUSDT', 'market_cap': 145681.37877062, 'volume': 1112921.1518, 'days_listed': 90}
# {'symbol': 'SNTUSDT', 'market_cap': 148982.6387980728, 'volume': 3234534.05988, 'days_listed': 90}
# {'symbol': 'BSWUSDT', 'market_cap': 152426.596900284, 'volume': 1910107.73058, 'days_listed': 90}
# {'symbol': 'RDNTUSDT', 'market_cap': 153809.16019392, 'volume': 2388340.9968, 'days_listed': 90}
# {'symbol': 'SKLUSDT', 'market_cap': 155681.2568055384, 'volume': 2902335.13806, 'days_listed': 90}
# {'symbol': 'CLVUSDT', 'market_cap': 156525.98664426358, 'volume': 2315473.175211, 'days_listed': 90}
# {'symbol': 'MDTUSDT', 'market_cap': 162273.2866861127, 'volume': 2648494.967947, 'days_listed': 90}
# {'symbol': 'DGBUSDT', 'market_cap': 169956.4945590943, 'volume': 11240508.899411, 'days_listed': 90}
# {'symbol': 'ALPHAUSDT', 'market_cap': 171653.91561188002, 'volume': 1941786.3757, 'days_listed': 90}
# {'symbol': 'LTOUSDT', 'market_cap': 183442.59471528, 'volume': 1171408.6508, 'days_listed': 90}
# {'symbol': 'RIFUSDT', 'market_cap': 188179.8175509, 'volume': 1690744.093, 'days_listed': 90}
# {'symbol': 'IOTXUSDT', 'market_cap': 194684.66400060643, 'volume': 4693458.63068, 'days_listed': 90}
# {'symbol': 'IDEXUSDT', 'market_cap': 205513.28697718476, 'volume': 3076085.720359, 'days_listed': 90}
# {'symbol': 'VIBUSDT', 'market_cap': 228974.0191307505, 'volume': 2379939.91405, 'days_listed': 90}
# {'symbol': 'TROYUSDT', 'market_cap': 235270.38421263252, 'volume': 54867160.497349, 'days_listed': 90}
# {'symbol': 'HFTUSDT', 'market_cap': 240411.743938127, 'volume': 1077596.34217, 'days_listed': 90}
# {'symbol': 'ICXUSDT', 'market_cap': 242007.12617203497, 'volume': 1224112.92955, 'days_listed': 90}
# {'symbol': 'TURBOUSDT', 'market_cap': 264705.7198923893, 'volume': 25739568.250913, 'days_listed': 90}
# {'symbol': 'LOKAUSDT', 'market_cap': 269058.454244831, 'volume': 1165259.65459, 'days_listed': 90}
# {'symbol': 'BEAMXUSDT', 'market_cap': 270553.1225320326, 'volume': 9417094.41462, 'days_listed': 90}
# {'symbol': 'RAREUSDT', 'market_cap': 283727.38901760004, 'volume': 2364394.90848, 'days_listed': 90}
# {'symbol': 'CHESSUSDT', 'market_cap': 284592.559074622, 'volume': 1386227.75974, 'days_listed': 90}
# {'symbol': 'HARDUSDT', 'market_cap': 300119.30075676, 'volume': 2044409.4057, 'days_listed': 90}
# {'symbol': 'PONDUSDT', 'market_cap': 300213.2451257118, 'volume': 12369725.79834, 'days_listed': 90}
# {'symbol': 'CTSIUSDT', 'market_cap': 303354.33514602, 'volume': 1772965.1382, 'days_listed': 90}
# {'symbol': 'TRUUSDT', 'market_cap': 312250.43774148, 'volume': 3232406.1878, 'days_listed': 90}
# {'symbol': 'DODOUSDT', 'market_cap': 324215.942040272, 'volume': 1967329.74539, 'days_listed': 90}
# {'symbol': 'AUDIOUSDT', 'market_cap': 326593.00644211296, 'volume': 1963878.57151, 'days_listed': 90}
# {'symbol': 'MAVUSDT', 'market_cap': 340535.27849385, 'volume': 1510134.2727, 'days_listed': 90}
# {'symbol': 'AERGOUSDT', 'market_cap': 341576.65913741995, 'volume': 2547178.6662, 'days_listed': 90}
# {'symbol': 'OGNUSDT', 'market_cap': 351423.55363850994, 'volume': 2726327.0259, 'days_listed': 90}
# {'symbol': 'ONEUSDT', 'market_cap': 361908.64136937517, 'volume': 11682009.082291, 'days_listed': 90}
# {'symbol': 'ADXUSDT', 'market_cap': 389299.4413256, 'volume': 1761535.9336, 'days_listed': 90}
# {'symbol': 'COTIUSDT', 'market_cap': 391855.8418184758, 'volume': 2889366.18359, 'days_listed': 90}
# {'symbol': 'ONGUSDT', 'market_cap': 392198.21782157, 'volume': 1152507.2519, 'days_listed': 90}
# {'symbol': 'ONTUSDT', 'market_cap': 408043.14715167, 'volume': 1594541.4113, 'days_listed': 90}
# {'symbol': 'XVGUSDT', 'market_cap': 422901.58144055743, 'volume': 27978933.605065, 'days_listed': 90}
# {'symbol': 'C98USDT', 'market_cap': 442510.39714917005, 'volume': 2403641.4837, 'days_listed': 90}
# {'symbol': 'STRAXUSDT', 'market_cap': 445133.5538957626, 'volume': 5679172.67027, 'days_listed': 90}
# {'symbol': 'PEOPLEUSDT', 'market_cap': 462372.8478932784, 'volume': 9397822.111652, 'days_listed': 90}
# {'symbol': 'UTKUSDT', 'market_cap': 492263.5297880928, 'volume': 5496466.38888, 'days_listed': 90}
# {'symbol': 'ASTRUSDT', 'market_cap': 499113.78897510003, 'volume': 7678673.67654, 'days_listed': 90}
# {'symbol': 'LRCUSDT', 'market_cap': 522941.86514304, 'volume': 2434552.4448, 'days_listed': 90}
# {'symbol': 'VOXELUSDT', 'market_cap': 556048.00166272, 'volume': 2920420.1768, 'days_listed': 90}
# {'symbol': 'CHZUSDT', 'market_cap': 613274.47480702, 'volume': 6673280.4658, 'days_listed': 90}
# {'symbol': 'DUSKUSDT', 'market_cap': 627713.7038070401, 'volume': 2492905.8928, 'days_listed': 90}
# {'symbol': 'BATUSDT', 'market_cap': 664913.6598256001, 'volume': 2593267.004, 'days_listed': 90}
# {'symbol': 'ACAUSDT', 'market_cap': 685137.3889576218, 'volume': 6379305.297557, 'days_listed': 90}
# {'symbol': 'HIFIUSDT', 'market_cap': 694559.076577551, 'volume': 1183436.83179, 'days_listed': 90}
# {'symbol': 'COMBOUSDT', 'market_cap': 707461.678005408, 'volume': 1485016.11672, 'days_listed': 90}
# {'symbol': 'VANRYUSDT', 'market_cap': 727966.38535582, 'volume': 5544298.4414, 'days_listed': 90}
# {'symbol': 'SFPUSDT', 'market_cap': 746447.5344516, 'volume': 1014884.4792, 'days_listed': 90}
# {'symbol': 'ROSEUSDT', 'market_cap': 753113.2172876444, 'volume': 8398719.942987, 'days_listed': 90}
# {'symbol': 'POLYXUSDT', 'market_cap': 755294.868469932, 'volume': 2633524.64599, 'days_listed': 90}
# {'symbol': 'BNXUSDT', 'market_cap': 757867.909155234, 'volume': 1725957.43374, 'days_listed': 90}
# {'symbol': 'DIAUSDT', 'market_cap': 785027.5701733921, 'volume': 1004128.38344, 'days_listed': 90}
# {'symbol': 'CVCUSDT', 'market_cap': 788222.5119949499, 'volume': 4272208.7371, 'days_listed': 90}
# {'symbol': 'STPTUSDT', 'market_cap': 816348.5005256698, 'volume': 12193405.534364, 'days_listed': 90}
# {'symbol': 'GLMRUSDT', 'market_cap': 818990.874451362, 'volume': 3041184.08634, 'days_listed': 90}
# {'symbol': 'BAKEUSDT', 'market_cap': 843779.1382430189, 'volume': 3069403.92231, 'days_listed': 90}
# {'symbol': 'NTRNUSDT', 'market_cap': 861783.474684195, 'volume': 2130490.66671, 'days_listed': 90}
# {'symbol': 'BURGERUSDT', 'market_cap': 871952.036975824, 'volume': 1870740.26384, 'days_listed': 90}
# {'symbol': 'TNSRUSDT', 'market_cap': 888957.6569360399, 'volume': 1826875.5794, 'days_listed': 90}
# {'symbol': 'KNCUSDT', 'market_cap': 894099.354775116, 'volume': 1513370.60727, 'days_listed': 90}
# {'symbol': 'OSMOUSDT', 'market_cap': 922184.4829334399, 'volume': 1921217.672778, 'days_listed': 90}
# {'symbol': 'ARKUSDT', 'market_cap': 930036.9396489599, 'volume': 1697767.3232, 'days_listed': 90}
# {'symbol': 'PIXELUSDT', 'market_cap': 948016.045971312, 'volume': 5435871.82323, 'days_listed': 90}
# {'symbol': 'SLFUSDT', 'market_cap': 953129.56646475, 'volume': 2762694.39555, 'days_listed': 90}
# {'symbol': 'GLMUSDT', 'market_cap': 956867.169119562, 'volume': 2427364.71111, 'days_listed': 90}
# {'symbol': 'CHRUSDT', 'market_cap': 969295.12166004, 'volume': 3783353.3242, 'days_listed': 90}
# {'symbol': 'FISUSDT', 'market_cap': 981224.20938967, 'volume': 2073154.8899, 'days_listed': 90}
# {'symbol': 'TKOUSDT', 'market_cap': 993350.92487445, 'volume': 2082496.69785, 'days_listed': 90}
# {'symbol': 'POWRUSDT', 'market_cap': 997651.45594478, 'volume': 3580945.6423, 'days_listed': 90}
# {'symbol': 'JASMYUSDT', 'market_cap': 1027260.1210129851, 'volume': 26272637.366061, 'days_listed': 90}
# {'symbol': 'MBOXUSDT', 'market_cap': 1029903.140837376, 'volume': 4814881.44384, 'days_listed': 90}
# {'symbol': 'BLURUSDT', 'market_cap': 1044835.96709142, 'volume': 3848382.93588, 'days_listed': 90}
# {'symbol': 'RSRUSDT', 'market_cap': 1046480.194284567, 'volume': 60799453.5373325, 'days_listed': 90}
# {'symbol': 'NFPUSDT', 'market_cap': 1055084.50203921, 'volume': 3359071.9581, 'days_listed': 90}
# {'symbol': 'GTCUSDT', 'market_cap': 1055178.8646912, 'volume': 1297882.9824, 'days_listed': 90}
# {'symbol': 'ALTUSDT', 'market_cap': 1076351.037838551, 'volume': 8324447.31507, 'days_listed': 90}
# {'symbol': 'TUSDUSDT', 'market_cap': 1082688.77429561, 'volume': 1081931.4223, 'days_listed': 90}
# {'symbol': 'LSKUSDT', 'market_cap': 1088902.4456701998, 'volume': 1091084.6149, 'days_listed': 90}
# {'symbol': 'ENJUSDT', 'market_cap': 1091435.6335836472, 'volume': 4526900.18077, 'days_listed': 90}
# {'symbol': 'BICOUSDT', 'market_cap': 1133062.4813858296, 'volume': 3327643.117139, 'days_listed': 90}
# {'symbol': 'WOOUSDT', 'market_cap': 1165985.826987364, 'volume': 4697767.23202, 'days_listed': 90}
# {'symbol': 'CATIUSDT', 'market_cap': 1195487.956476208, 'volume': 3068500.91498, 'days_listed': 90}
# {'symbol': 'CFXUSDT', 'market_cap': 1227222.3659776, 'volume': 6964939.648, 'days_listed': 90}
# {'symbol': 'EDUUSDT', 'market_cap': 1244002.4189722799, 'volume': 2183609.6524, 'days_listed': 90}
# {'symbol': 'LISTAUSDT', 'market_cap': 1246662.959265864, 'volume': 2674094.72172, 'days_listed': 90}
# {'symbol': 'VETUSDT', 'market_cap': 1278157.154894606, 'volume': 25235086.967317, 'days_listed': 90}
# {'symbol': 'STORJUSDT', 'market_cap': 1288440.7901395198, 'volume': 2498915.4192, 'days_listed': 90}
# {'symbol': 'DFUSDT', 'market_cap': 1360694.8210903308, 'volume': 14327627.89397, 'days_listed': 90}
# {'symbol': 'SXPUSDT', 'market_cap': 1362489.392006106, 'volume': 4000262.45451, 'days_listed': 90}
# {'symbol': 'JOEUSDT', 'market_cap': 1426507.7482397058, 'volume': 3504933.042358, 'days_listed': 90}
# {'symbol': 'FIDAUSDT', 'market_cap': 1428822.8025696152, 'volume': 5321500.19579, 'days_listed': 90}
# {'symbol': 'PORTALUSDT', 'market_cap': 1666110.3511500002, 'volume': 4698562.75, 'days_listed': 90}
# {'symbol': 'AEVOUSDT', 'market_cap': 1670094.7082459521, 'volume': 4133897.792688, 'days_listed': 90}
# {'symbol': 'PROSUSDT', 'market_cap': 1673370.11054255, 'volume': 2907680.4701, 'days_listed': 90}
# {'symbol': 'BANDUSDT', 'market_cap': 1757417.1835076, 'volume': 1123668.2759, 'days_listed': 90}
# {'symbol': 'IDUSDT', 'market_cap': 1789196.00625051, 'volume': 3791472.7829, 'days_listed': 90}
# {'symbol': 'CTKUSDT', 'market_cap': 1841929.8099924482, 'volume': 2180314.64251, 'days_listed': 90}
# {'symbol': 'FLUXUSDT', 'market_cap': 1878165.176150287, 'volume': 2762820.206164, 'days_listed': 90}
# {'symbol': 'YGGUSDT', 'market_cap': 1931594.937934702, 'volume': 3556610.08642, 'days_listed': 90}
# {'symbol': 'GALAUSDT', 'market_cap': 2039353.9226701749, 'volume': 48521387.64383, 'days_listed': 90}
# {'symbol': 'ELFUSDT', 'market_cap': 2071496.610686665, 'volume': 4316517.21335, 'days_listed': 90}
# {'symbol': 'PYTHUSDT', 'market_cap': 2284668.032888696, 'volume': 5870164.52438, 'days_listed': 90}
# {'symbol': 'LITUSDT', 'market_cap': 2391606.6966213, 'volume': 2536168.2891, 'days_listed': 90}
# {'symbol': 'PERPUSDT', 'market_cap': 2458382.592193756, 'volume': 2976970.92782, 'days_listed': 90}
# {'symbol': 'AXLUSDT', 'market_cap': 2545623.8720346, 'volume': 3414653.0812, 'days_listed': 90}
# {'symbol': 'XAIUSDT', 'market_cap': 2655204.145327725, 'volume': 10076676.07335, 'days_listed': 90}
# {'symbol': '1INCHUSDT', 'market_cap': 2800019.955644024, 'volume': 6597596.50246, 'days_listed': 90}
# {'symbol': 'ZKUSDT', 'market_cap': 2844547.22401738, 'volume': 13500461.4334, 'days_listed': 90}
# {'symbol': 'GRTUSDT', 'market_cap': 2879977.18468856, 'volume': 12009913.1972, 'days_listed': 90}
# {'symbol': 'SYNUSDT', 'market_cap': 2880880.222989254, 'volume': 4340636.16542, 'days_listed': 90}
# {'symbol': 'TWTUSDT', 'market_cap': 2887709.551562, 'volume': 2292742.796, 'days_listed': 90}
# {'symbol': 'ERNUSDT', 'market_cap': 2903717.2842906, 'volume': 1049789.3291, 'days_listed': 90}
# {'symbol': 'EURIUSDT', 'market_cap': 2977432.064090799, 'volume': 2885947.52747, 'days_listed': 90}
# {'symbol': 'NEXOUSDT', 'market_cap': 2982651.4862118796, 'volume': 2136569.83253, 'days_listed': 90}
# {'symbol': 'HOOKUSDT', 'market_cap': 2994119.1581335957, 'volume': 6545953.55954, 'days_listed': 90}
# {'symbol': 'BALUSDT', 'market_cap': 3072794.2393979602, 'volume': 1099783.19234, 'days_listed': 90}
# {'symbol': 'WUSDT', 'market_cap': 3414634.855319886, 'volume': 11007849.30793, 'days_listed': 90}
# {'symbol': 'ALICEUSDT', 'market_cap': 3543965.0647960496, 'volume': 2805989.75835, 'days_listed': 90}
# {'symbol': 'FLOWUSDT', 'market_cap': 3564050.3423524005, 'volume': 4511456.12956, 'days_listed': 90}
# {'symbol': 'RADUSDT', 'market_cap': 3722405.2540125, 'volume': 2707203.8211, 'days_listed': 90}
# {'symbol': 'BBUSDT', 'market_cap': 3752490.334871395, 'volume': 8274510.10997, 'days_listed': 90}
# {'symbol': 'XNOUSDT', 'market_cap': 3765975.99271128, 'volume': 2337663.55848, 'days_listed': 90}
# {'symbol': 'LUNAUSDT', 'market_cap': 3798637.3085088287, 'volume': 8181428.620523, 'days_listed': 90}
# {'symbol': 'API3USDT', 'market_cap': 4137210.44504508, 'volume': 2306137.37182, 'days_listed': 90}
# {'symbol': 'ATAUSDT', 'market_cap': 4324252.7454609, 'volume': 21675452.3582, 'days_listed': 90}
# {'symbol': 'BELUSDT', 'market_cap': 4483142.26375473, 'volume': 7314639.0337, 'days_listed': 90}
# {'symbol': 'PYRUSDT', 'market_cap': 4565308.944703249, 'volume': 1401691.416857, 'days_listed': 90}
# {'symbol': 'CELOUSDT', 'market_cap': 4566130.543391454, 'volume': 6400519.40481, 'days_listed': 90}
# {'symbol': 'PSGUSDT', 'market_cap': 4667347.88849124, 'volume': 1387852.47948, 'days_listed': 90}
# {'symbol': 'DYMUSDT', 'market_cap': 4711650.817112801, 'volume': 3149499.2093, 'days_listed': 90}
# {'symbol': 'MINAUSDT', 'market_cap': 5029394.822403456, 'volume': 7693735.38688, 'days_listed': 90}
# {'symbol': 'FIROUSDT', 'market_cap': 5409768.3677904, 'volume': 2621011.8061, 'days_listed': 90}
# {'symbol': 'DARUSDT', 'market_cap': 5613329.661734375, 'volume': 25660935.5965, 'days_listed': 90}
# {'symbol': 'KDAUSDT', 'market_cap': 5701449.671097106, 'volume': 5593495.213477, 'days_listed': 90}
# {'symbol': 'SANTOSUSDT', 'market_cap': 5935602.2490021, 'volume': 1752983.53485, 'days_listed': 90}
# {'symbol': 'MANAUSDT', 'market_cap': 5990158.27958704, 'volume': 10918990.6664, 'days_listed': 90}
# {'symbol': 'QTUMUSDT', 'market_cap': 6154126.8614972, 'volume': 1803671.4131, 'days_listed': 90}
# {'symbol': 'ZRXUSDT', 'market_cap': 6439532.2652764805, 'volume': 12086209.2066, 'days_listed': 90}
# {'symbol': 'HIGHUSDT', 'market_cap': 6668952.342307083, 'volume': 4250447.636907, 'days_listed': 90}
# {'symbol': 'WINGUSDT', 'market_cap': 6716769.90778066, 'volume': 1119648.25934, 'days_listed': 90}
# {'symbol': 'STRKUSDT', 'market_cap': 6824334.527151669, 'volume': 13045946.333687, 'days_listed': 90}
# {'symbol': 'GMTUSDT', 'market_cap': 6879268.029171154, 'volume': 43049236.72823, 'days_listed': 90}
# {'symbol': 'RLCUSDT', 'market_cap': 6958616.253302099, 'volume': 2860097.1037, 'days_listed': 90}
# {'symbol': 'SCRTUSDT', 'market_cap': 6981188.684406546, 'volume': 12569659.13649, 'days_listed': 90}
# {'symbol': 'RONINUSDT', 'market_cap': 7364906.408675881, 'volume': 3669609.57084, 'days_listed': 90}
# {'symbol': 'PHBUSDT', 'market_cap': 7530694.2449596, 'volume': 4330473.9764, 'days_listed': 90}
# {'symbol': 'IMXUSDT', 'market_cap': 7779006.815910071, 'volume': 5295443.71403, 'days_listed': 90}
# {'symbol': 'STEEMUSDT', 'market_cap': 7979096.891667601, 'volume': 29552210.70988, 'days_listed': 90}
# {'symbol': 'IOTAUSDT', 'market_cap': 8043390.656346, 'volume': 22593793.9785, 'days_listed': 90}
# {'symbol': 'ACEUSDT', 'market_cap': 8125823.9079268, 'volume': 3600276.4324, 'days_listed': 90}
# {'symbol': 'MAGICUSDT', 'market_cap': 8166235.744821, 'volume': 14140667.9564, 'days_listed': 90}
# {'symbol': 'POLUSDT', 'market_cap': 8308193.559268745, 'volume': 15983442.78428, 'days_listed': 90}
# {'symbol': 'HIVEUSDT', 'market_cap': 8482715.612115039, 'volume': 22130747.7488, 'days_listed': 90}
# {'symbol': 'JUPUSDT', 'market_cap': 8600233.208471352, 'volume': 9114278.51682, 'days_listed': 90}
# {'symbol': 'SUPERUSDT', 'market_cap': 8883982.48640056, 'volume': 5600795.9188, 'days_listed': 90}
# {'symbol': 'LQTYUSDT', 'market_cap': 9027422.5547795, 'volume': 4617607.4449, 'days_listed': 90}
# {'symbol': 'KAVAUSDT', 'market_cap': 9548615.321081836, 'volume': 17465914.25111, 'days_listed': 90}
# {'symbol': 'SAGAUSDT', 'market_cap': 10147427.106945831, 'volume': 6325537.40615, 'days_listed': 90}
# {'symbol': 'CYBERUSDT', 'market_cap': 10590701.495481921, 'volume': 2945133.89752, 'days_listed': 90}
# {'symbol': 'MANTAUSDT', 'market_cap': 10661012.576256, 'volume': 11105221.4336, 'days_listed': 90}
# {'symbol': 'AVAUSDT', 'market_cap': 10803946.12913851, 'volume': 7556263.90344, 'days_listed': 90}
# {'symbol': 'OGUSDT', 'market_cap': 11525238.616545498, 'volume': 2343004.3945, 'days_listed': 90}
# {'symbol': 'CTXCUSDT', 'market_cap': 11767601.78453392, 'volume': 39017247.2962, 'days_listed': 90}
# {'symbol': 'BADGERUSDT', 'market_cap': 12102716.45956175, 'volume': 2817861.80665, 'days_listed': 90}
# {'symbol': 'DEGOUSDT', 'market_cap': 12131031.776528, 'volume': 3868313.70425, 'days_listed': 90}
# {'symbol': 'XTZUSDT', 'market_cap': 12497111.3806244, 'volume': 8850645.4537, 'days_listed': 90}
# {'symbol': 'GASUSDT', 'market_cap': 13248163.3403175, 'volume': 2617696.7675, 'days_listed': 90}
# {'symbol': 'SNXUSDT', 'market_cap': 14295864.32021, 'volume': 6542729.666, 'days_listed': 90}
# {'symbol': 'MASKUSDT', 'market_cap': 14862514.745693602, 'volume': 4712274.8084, 'days_listed': 90}
# {'symbol': 'ALGOUSDT', 'market_cap': 14906303.286272, 'volume': 36392342.0075, 'days_listed': 90}
# {'symbol': 'SEIUSDT', 'market_cap': 16085143.137291145, 'volume': 34606590.22653, 'days_listed': 90}
# {'symbol': 'AIUSDT', 'market_cap': 17220650.72952413, 'volume': 22991523.00337, 'days_listed': 90}
# {'symbol': 'RPLUSDT', 'market_cap': 18365056.482996, 'volume': 1478667.9938, 'days_listed': 90}
# {'symbol': 'ARKMUSDT', 'market_cap': 18850905.088205397, 'volume': 11480453.7687, 'days_listed': 90}
# {'symbol': 'CREAMUSDT', 'market_cap': 19057363.9266816, 'volume': 1369063.50048, 'days_listed': 90}
# {'symbol': 'EOSUSDT', 'market_cap': 20392474.6592152, 'volume': 22703712.60211, 'days_listed': 90}
# {'symbol': 'APEUSDT', 'market_cap': 20698157.34077235, 'volume': 15388964.56563, 'days_listed': 90}
# {'symbol': 'STXUSDT', 'market_cap': 21642932.4336371, 'volume': 12561191.1977, 'days_listed': 90}
# {'symbol': 'JTOUSDT', 'market_cap': 22330729.6862544, 'volume': 7240833.2316, 'days_listed': 90}
# {'symbol': 'STGUSDT', 'market_cap': 23987958.55982492, 'volume': 49520971.42821, 'days_listed': 90}
# {'symbol': 'THETAUSDT', 'market_cap': 25939205.6975744, 'volume': 10527275.0396, 'days_listed': 90}
# {'symbol': 'NMRUSDT', 'market_cap': 29454404.856348, 'volume': 1746999.1018, 'days_listed': 90}
# {'symbol': 'DYDXUSDT', 'market_cap': 29640779.69437347, 'volume': 18439054.242223, 'days_listed': 90}
# {'symbol': 'SANDUSDT', 'market_cap': 29958528.564434722, 'volume': 46033387.4684, 'days_listed': 90}
# {'symbol': 'CVXUSDT', 'market_cap': 31162809.579439957, 'volume': 5737950.576218, 'days_listed': 90}
# {'symbol': 'EURUSDT', 'market_cap': 31856602.91417976, 'volume': 30868801.27343, 'days_listed': 90}
# {'symbol': 'FXSUSDT', 'market_cap': 34227637.4271527, 'volume': 8929725.3919, 'days_listed': 90}
# {'symbol': 'UMAUSDT', 'market_cap': 34294140.326740004, 'volume': 10921700.741, 'days_listed': 90}
# {'symbol': 'XVSUSDT', 'market_cap': 38805906.037116, 'volume': 3845976.8124, 'days_listed': 90}
# {'symbol': 'HBARUSDT', 'market_cap': 39389578.62437744, 'volume': 128926350.56421, 'days_listed': 90}
# {'symbol': 'PHAUSDT', 'market_cap': 40881090.66533262, 'volume': 115679373.6993, 'days_listed': 90}
# {'symbol': 'TRXUSDT', 'market_cap': 42296457.577167675, 'volume': 156133102.90575, 'days_listed': 90}
# {'symbol': 'FTMUSDT', 'market_cap': 43945846.1362164, 'volume': 52692861.0746, 'days_listed': 90}
# {'symbol': 'LDOUSDT', 'market_cap': 47072474.62616118, 'volume': 23268647.86266, 'days_listed': 90}
# {'symbol': 'OMUSDT', 'market_cap': 47547055.59300294, 'volume': 12123474.7426, 'days_listed': 90}
# {'symbol': 'OMNIUSDT', 'market_cap': 47575098.356016, 'volume': 5148820.1684, 'days_listed': 90}
# {'symbol': 'CRVUSDT', 'market_cap': 50434366.58710983, 'volume': 47895884.69811, 'days_listed': 90}
# {'symbol': 'MOVRUSDT', 'market_cap': 52057447.368853204, 'volume': 3730914.310102, 'days_listed': 90}
# {'symbol': 'CAKEUSDT', 'market_cap': 54361799.95649037, 'volume': 19263571.91938, 'days_listed': 90}
# {'symbol': 'GMXUSDT', 'market_cap': 54418501.0160092, 'volume': 1846572.82036, 'days_listed': 90}
# {'symbol': 'FETUSDT', 'market_cap': 54739638.5897116, 'volume': 36886548.9149, 'days_listed': 90}
# {'symbol': 'ETHFIUSDT', 'market_cap': 55535767.3002146, 'volume': 23442704.6434, 'days_listed': 90}
# {'symbol': 'ARBUSDT', 'market_cap': 63584078.05599278, 'volume': 72386245.51001, 'days_listed': 90}
# {'symbol': 'PENDLEUSDT', 'market_cap': 63605284.346857, 'volume': 11728800.359, 'days_listed': 90}
# {'symbol': 'AGLDUSDT', 'market_cap': 65670204.05551309, 'volume': 23802176.1709, 'days_listed': 90}
# {'symbol': 'AXSUSDT', 'market_cap': 66518909.42071789, 'volume': 9549082.60418, 'days_listed': 90}
# {'symbol': 'XLMUSDT', 'market_cap': 66565667.469436996, 'volume': 148385348.795, 'days_listed': 90}
# {'symbol': 'FTTUSDT', 'market_cap': 74882264.80677168, 'volume': 22446722.06438, 'days_listed': 90}
# {'symbol': 'ZROUSDT', 'market_cap': 75204430.5332973, 'volume': 13115526.77595, 'days_listed': 90}
# {'symbol': 'IOUSDT', 'market_cap': 83973021.32741521, 'volume': 23025232.06126, 'days_listed': 90}
# {'symbol': 'RAYUSDT', 'market_cap': 84709512.5995395, 'volume': 15304338.3197, 'days_listed': 90}
# {'symbol': 'OPUSDT', 'market_cap': 85322702.83587512, 'volume': 41479194.37816, 'days_listed': 90}

# %% [markdown]
# ## use pandas to filter  coins with marketcap =<  100 Million Dollars

# %%
import os
from binance.client import Client
import pandas as pd
from dotenv import load_dotenv
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

# Load environment variables
load_dotenv()

API_KEY = os.getenv('BINANCE_API_KEY')
API_SECRET = os.getenv('BINANCE_API_SECRET')

client = Client(API_KEY, API_SECRET)

def get_filtered_symbols_parallel(market_cap_threshold=100_000_000, min_volume=1_000_000, min_days_listed=90):
    """
    Fetch USDT trading pairs with specific conditions using parallel processing:
      - Market cap below the threshold.
      - Minimum 24-hour trading volume.
      - Listed for at least the specified number of days.

    Returns:
        list: Filtered symbols meeting the criteria.
    """
    print("Fetching exchange info...")
    exchange_info = client.get_exchange_info()
    symbols = [
        symbol_info['symbol'] for symbol_info in exchange_info['symbols']
        if symbol_info['symbol'].endswith('USDT') and symbol_info['status'] == 'TRADING'
    ]

    def process_symbol(symbol):
        try:
            ticker_24hr = client.get_ticker(symbol=symbol)
            volume = float(ticker_24hr['quoteVolume'])
            price = float(ticker_24hr['lastPrice'])
            market_cap = volume * price

            # Fetch listing age (minimum 90 daily klines required)
            klines = client.get_klines(symbol=symbol, interval='1d', limit=min_days_listed)

            if (
                market_cap < market_cap_threshold
                and volume >= min_volume
                and len(klines) >= min_days_listed
            ):
                return {
                    'symbol': symbol,
                    'market_cap': market_cap,
                    'volume': volume,
                    'days_listed': len(klines)
                }
        except Exception as e:
            print(f"Error processing {symbol}: {e}")
        return None

    print("Processing symbols in parallel...")
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(process_symbol, symbols), total=len(symbols), desc="Processing symbols"))

    filtered_symbols = [result for result in results if result is not None]
    return sorted(filtered_symbols, key=lambda x: x['market_cap'])

def fetch_historical_data(symbol, interval='15m', days=14):
    """
    Fetch historical OHLC and volume data for a given symbol.

    Args:
        symbol (str): The cryptocurrency trading pair symbol (e.g., BonkUSDT).
        interval (str): The time interval for the kline data (e.g., '15m').
        days (int): Number of days to fetch data for.

    Returns:
        pd.DataFrame: DataFrame containing OHLC and volume data.
    """
    try:
        print(f"Fetching historical data for {symbol} ({interval}, {days} days)...")
        since = int((pd.Timestamp.utcnow() - pd.Timedelta(days=days)).timestamp() * 1000)

        klines = client.get_historical_klines(symbol, interval, start_str=since)

        data = [{
            'timestamp': pd.to_datetime(kline[0], unit='ms'),
            'open': float(kline[1]),
            'high': float(kline[2]),
            'low': float(kline[3]),
            'close': float(kline[4]),
            'volume': float(kline[5])
        } for kline in klines]

        return pd.DataFrame(data)

    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return pd.DataFrame()

def main():
   
    filtered_symbols = get_filtered_symbols_parallel()

    if not filtered_symbols:
        print("No symbols met the criteria.")
    else:
        print(f"Filtered symbols found: {len(filtered_symbols)}")

        all_data = []
        for symbol_data in tqdm(filtered_symbols[:4], desc="Fetching historical data"):
            symbol = symbol_data['symbol']
            ohlc_data = fetch_historical_data(symbol, interval='15m', days=14)

            if not ohlc_data.empty:
                ohlc_data['symbol'] = symbol.replace('USDT', '')                                    
                ohlc_data['market_cap'] = symbol_data['market_cap']
                # ohlc_data['market_cap'] = ohlc_data['market_cap'].apply(lambda x: "{:,.2f}".format(x * 1_000_000))
                ohlc_data['market_cap'] = ohlc_data['market_cap'] * 1e6
                ohlc_data['volume'] = symbol_data['volume']

                


                ohlc_data[['open', 'high', 'low', 'close']] = ohlc_data[['open', 'high', 'low', 'close']].map(lambda x: f"{x:.8f}")
               
                all_data.append(ohlc_data[['timestamp','symbol', 'market_cap','open', 'high', 'low', 'close', 'volume']])

        
        if all_data:
            combined_data = pd.concat(all_data, ignore_index=True)
            combined_data.to_csv("small_capped_coins.csv", index=False)
            print("Historical data and market cap information saved to small_capped_coins.csv.")
        else:
            print("No historical data available for the filtered symbols.")

if __name__ == "__main__":
    main()
# Out:
# Fetching exchange info...
# Processing symbols in parallel...
# Processing symbols:  25%|██▍       | 96/388 [00:10<00:28, 10.37it/s]
# Processing symbols: 100%|██████████| 388/388 [00:40<00:00,  9.65it/s]
# Filtered symbols found: 278
# Fetching historical data:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching historical data for BTTCUSDT (15m, 14 days)...
# Fetching historical data:  25%|██▌       | 1/4 [00:03<00:11,  3.88s/it]
# Fetching historical data for XECUSDT (15m, 14 days)...
# Fetching historical data:  50%|█████     | 2/4 [00:07<00:07,  3.52s/it]
# Fetching historical data for WINUSDT (15m, 14 days)...
# Fetching historical data:  75%|███████▌  | 3/4 [00:10<00:03,  3.51s/it]
# Fetching historical data for LUNCUSDT (15m, 14 days)...
# Fetching historical data: 100%|██████████| 4/4 [00:14<00:00,  3.56s/it]
# Historical data and market cap information saved to small_capped_coins.csv.

# %% [markdown]
# ### Preprocess , Prepare  and Normalise the Data

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

def preprocess_and_normalize_data(input_file, output_file, min_volume_threshold=1_000_000, max_market_cap=100_000_000):
    """
    Preprocess and normalize the data:
    - Handle missing values.
    - Remove low-volume assets.
    - Remove high market cap assets.
    - Normalize numeric columns.
    - Save the preprocessed data to a new file.

    Args:
        input_file (str): Path to the CSV file to preprocess.
        output_file (str): Path to save the preprocessed and normalized data.
        min_volume_threshold (float): Minimum volume threshold to filter assets.
        max_market_cap (float): Maximum market cap threshold to filter assets.
    """
    print(f"Loading data from {input_file}...")
    try:
        data = pd.read_csv(input_file)

        # Handle missing values by interpolation
        print("Handling missing values...")
        for col in tqdm(data.columns, desc="Interpolating missing values"):
            data[col] = data[col].interpolate(method='linear', limit_direction='forward')
        data.dropna(inplace=True)

        # Remove low-volume assets (if 'volume' column exists)
        if 'volume' in data.columns:
            print("Removing low-volume assets...")
            data = data[data['volume'] >= min_volume_threshold]

        # Remove high market cap assets (if 'market_cap' column exists)
        if 'market_cap' in data.columns:
            print("Removing high market cap assets...")
            data = data[data['market_cap'] <= max_market_cap]

        # Normalize numeric columns
        print("Normalizing data...")
        numeric_cols = ['open', 'high', 'low', 'close']
        scaler = MinMaxScaler()
        for col in tqdm(numeric_cols, desc="Normalizing numeric columns"):
            data[col] = scaler.fit_transform(data[[col]])

        # Round volume and market_cap values to 2 decimal places
        data['volume'] = data['volume'].round(2)
        data['market_cap'] = data['market_cap'].round(2)

        # Save the preprocessed data
        print(f"Saving preprocessed data to {output_file}...")
        data.to_csv(output_file, index=False)
        print("Preprocessing complete.")

    except Exception as e:
        print(f"Error during preprocessing: {e}")

if __name__ == "__main__":
    input_csv = "small_capped_coins.csv"  
    output_csv = "preprocessed_small_capped_coins.csv" 
    preprocess_and_normalize_data(input_csv, output_csv)
# Out:
# Loading data from small_capped_coins.csv...
# Handling missing values...
# Interpolating missing values:   0%|          | 0/8 [00:00<?, ?it/s]/tmp/ipykernel_6161/5171982.py:27: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data[col] = data[col].interpolate(method='linear', limit_direction='forward')
# Interpolating missing values: 100%|██████████| 8/8 [00:00<00:00, 211.97it/s]
# Removing low-volume assets...
# Removing high market cap assets...
# Normalizing data...
# Normalizing numeric columns: 100%|██████████| 4/4 [00:00<00:00, 57.39it/s]
# Saving preprocessed data to preprocessed_small_capped_coins.csv...
# Preprocessing complete.

# %% [markdown]
# Merge from Data Collection to Preprocessing and Normalization together

# %%
import os
from binance.client import Client
import pandas as pd
from dotenv import load_dotenv
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import MinMaxScaler

# Load environment variables
load_dotenv()

API_KEY = os.getenv('BINANCE_API_KEY')
API_SECRET = os.getenv('BINANCE_API_SECRET')

client = Client(API_KEY, API_SECRET)

def preprocess_and_normalize_data(data, min_volume_threshold=1_000_000, max_market_cap=100_000_000):
    """
    Preprocess and normalize the data:
    - Handle missing values.
    - Remove low-volume assets.
    - Remove high market cap assets.
    - Normalize numeric columns.

    Args:
        data (pd.DataFrame): DataFrame containing the data to preprocess.
        min_volume_threshold (float): Minimum volume threshold to filter assets.
        max_market_cap (float): Maximum market cap threshold to filter assets.

    Returns:
        pd.DataFrame: Preprocessed and normalized DataFrame.
    """
    # Handle missing values by interpolation
    print("Handling missing values...")
    for col in tqdm(data.columns, desc="Interpolating missing values"):
        data[col] = data[col].interpolate(method='linear', limit_direction='forward')
    data.dropna(inplace=True)

    # Remove low-volume assets (if 'volume' column exists)
    if 'volume' in data.columns:
        print("Removing low-volume assets...")
        data = data[data['volume'] >= min_volume_threshold]

    # Remove high market cap assets (if 'market_cap' column exists)
    if 'market_cap' in data.columns:
        print("Removing high market cap assets...")
        data = data[data['market_cap'] <= max_market_cap]

    # Normalize numeric columns
    print("Normalizing data...")
    numeric_cols = ['open', 'high', 'low', 'close']
    scaler = MinMaxScaler()
    for col in tqdm(numeric_cols, desc="Normalizing numeric columns"):
        data[col] = scaler.fit_transform(data[[col]])

    # Round volume and market_cap values to 2 decimal places
    data['volume'] = data['volume'].round(2)
    data['market_cap'] = data['market_cap'].round(2)

    return data

def get_filtered_symbols_parallel(market_cap_threshold=100_000_000, min_volume=1_000_000, min_days_listed=90):
    """
    Fetch USDT trading pairs with specific conditions using parallel processing:
      - Market cap below the threshold.
      - Minimum 24-hour trading volume.
      - Listed for at least the specified number of days.

    Returns:
        list: Filtered symbols meeting the criteria.
    """
    print("Fetching exchange info...")
    exchange_info = client.get_exchange_info()
    symbols = [
        symbol_info['symbol'] for symbol_info in exchange_info['symbols']
        if symbol_info['symbol'].endswith('USDT') and symbol_info['status'] == 'TRADING'
    ]

    def process_symbol(symbol):
        try:
            ticker_24hr = client.get_ticker(symbol=symbol)
            volume = float(ticker_24hr['quoteVolume'])
            price = float(ticker_24hr['lastPrice'])
            market_cap = volume * price

            # Fetch listing age (minimum 90 daily klines required)
            klines = client.get_klines(symbol=symbol, interval='1d', limit=min_days_listed)

            if (
                market_cap < market_cap_threshold
                and volume >= min_volume
                and len(klines) >= min_days_listed
            ):
                return {
                    'symbol': symbol,
                    'market_cap': market_cap,
                    'volume': volume,
                    'days_listed': len(klines)
                }
        except Exception as e:
            print(f"Error processing {symbol}: {e}")
        return None

    print("Processing symbols in parallel...")
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(process_symbol, symbols), total=len(symbols), desc="Processing symbols"))

    filtered_symbols = [result for result in results if result is not None]
    return sorted(filtered_symbols, key=lambda x: x['market_cap'])

def fetch_historical_data(symbol, interval='15m', days=14):
    """
    Fetch historical OHLC and volume data for a given symbol.

    Args:
        symbol (str): The cryptocurrency trading pair symbol (e.g., BonkUSDT).
        interval (str): The time interval for the kline data (e.g., '15m').
        days (int): Number of days to fetch data for.

    Returns:
        pd.DataFrame: DataFrame containing OHLC and volume data.
    """
    try:
        print(f"Fetching historical data for {symbol} ({interval}, {days} days)...")
        since = int((pd.Timestamp.utcnow() - pd.Timedelta(days=days)).timestamp() * 1000)

        klines = client.get_historical_klines(symbol, interval, start_str=since)

        data = [{
            'timestamp': pd.to_datetime(kline[0], unit='ms'),
            'open': float(kline[1]),
            'high': float(kline[2]),
            'low': float(kline[3]),
            'close': float(kline[4]),
            'volume': float(kline[5])
        } for kline in klines]

        return pd.DataFrame(data)

    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return pd.DataFrame()

def main():
   
    filtered_symbols = get_filtered_symbols_parallel()

    if not filtered_symbols:
        print("No symbols met the criteria.")
    else:
        print(f"Filtered symbols found: {len(filtered_symbols)}")

        all_data = pd.DataFrame()
        for symbol_data in tqdm(filtered_symbols[:4], desc="Fetching historical data"):
            symbol = symbol_data['symbol']
            ohlc_data = fetch_historical_data(symbol, interval='15m', days=14)

            if not ohlc_data.empty:
                modified_symbol = symbol.replace('USDT', '')  
                ohlc_data['symbol'] = modified_symbol  
                ohlc_data['market_cap'] = symbol_data['market_cap']
                ohlc_data['volume'] = symbol_data['volume']

                ohlc_data[['open', 'high', 'low', 'close']] = ohlc_data[['open', 'high', 'low', 'close']].map(lambda x: f"{x:.8f}")
               
                all_data = pd.concat([all_data, ohlc_data], ignore_index=True)

        
        if not all_data.empty:
            preprocessed_data = preprocess_and_normalize_data(all_data)
            preprocessed_data.to_csv("small_capped_coinss.csv", index=False)
            print("Historical data and market cap information saved to small_capped_coins.csv.")
        else:
            print("No historical data available for the filtered symbols.")

if __name__ == "__main__":
    main()
# Out:
# Fetching exchange info...
# Processing symbols in parallel...
# Processing symbols: 100%|██████████| 388/388 [00:42<00:00,  9.20it/s]
# Filtered symbols found: 273
# Fetching historical data:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching historical data for BTTCUSDT (15m, 14 days)...
# Fetching historical data:  25%|██▌       | 1/4 [00:02<00:08,  2.97s/it]
# Fetching historical data for XECUSDT (15m, 14 days)...
# Fetching historical data:  50%|█████     | 2/4 [00:06<00:07,  3.53s/it]
# Fetching historical data for WINUSDT (15m, 14 days)...
# Fetching historical data:  75%|███████▌  | 3/4 [00:10<00:03,  3.63s/it]
# Fetching historical data for LUNCUSDT (15m, 14 days)...
# Fetching historical data: 100%|██████████| 4/4 [00:13<00:00,  3.38s/it]
# Handling missing values...
# Interpolating missing values:   0%|          | 0/8 [00:00<?, ?it/s]/tmp/ipykernel_6161/3600408681.py:36: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data[col] = data[col].interpolate(method='linear', limit_direction='forward')
# Interpolating missing values: 100%|██████████| 8/8 [00:00<00:00, 116.19it/s]
# Removing low-volume assets...
# Removing high market cap assets...
# Normalizing data...
# Normalizing numeric columns: 100%|██████████| 4/4 [00:00<00:00, 23.07it/s]
# Historical data and market cap information saved to small_capped_coins.csv.

# %% [markdown]
# # TECHNICAL INDICATORS
